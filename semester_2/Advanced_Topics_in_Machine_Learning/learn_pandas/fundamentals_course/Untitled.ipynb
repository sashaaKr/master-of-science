# %%
import numpy as np
import pandas as pd
import os

my_numpy_array = np.random.rand(3)
my_series = pd.Series(my_numpy_array)

array_2d = np.random.rand(3, 2)
# print(array_2d)

df = pd.DataFrame(array_2d)
df.columns = ["First", "Second"]
# print(df)
# print(df["Second"])

CSV_PATH = os.path.join(".", "artwork_data.csv")
# df2 = pd.read_csv(CSV_PATH, nrows=5)
# print(df2)

# df_index = pd.read_csv(CSV_PATH, nrows=5, index_col="id")
# print(df_index)

# df_limited = pd.read_csv(CSV_PATH, nrows=5, index_col="id", usecols=["id", "artist"])
# print(df_limited)

COLS_TO_USE = ["id", "artist", "title", "medium", "year", "acquisitionYear","height","width","units"]
df_with_specific_cols = pd.read_csv(CSV_PATH, index_col="id", usecols=COLS_TO_USE)
print(df_with_specific_cols)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5c2fdf8f00bf> in <module>
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import os
#       4
#       5 my_numpy_array = np.random.rand(3)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
artists = df_with_specific_cols["artist"]
print(artists)
print("==============")
print(len(pd.unique(artists)))
# Out:
# id
# 1035           Blake, Robert
# 1036           Blake, Robert
# 1037           Blake, Robert
# 1038           Blake, Robert
# 1039          Blake, William
#                  ...
# 122960    P-Orridge, Genesis
# 122961    P-Orridge, Genesis
# 121181          Hatoum, Mona
# 112306         Creed, Martin
# 127035     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object
# ...
#
# 3336

# %%
s = artists == "Bacon, Francis"
print(s)
print("==============")
print(s.value_counts())
# Out:
# id
# 1035      False
# 1036      False
# 1037      False
# 1038      False
# 1039      False
#           ...
# 122960    False
# 122961    False
# 121181    False
# 112306    False
# 127035    False
# Name: artist, Length: 69201, dtype: bool
# ...
# False    69151
# True        50
# Name: artist, dtype: int64

# %%
df_with_specific_cols.loc[1035, "artist"]
# Out:
# 'Blake, Robert'

# %%
df_with_specific_cols.loc[df_with_specific_cols["artist"] == "Bacon, Francis", :]
# Out:
#                artist                                              title  \
# id
# 672    Bacon, Francis                              Figure in a Landscape
# 673    Bacon, Francis                                     Study of a Dog
# 674    Bacon, Francis  Three Studies for Figures at the Base of a Cru...
# 677    Bacon, Francis                Study for a Portrait of Van Gogh IV
# 678    Bacon, Francis                                    Reclining Woman
# 679    Bacon, Francis                                      Seated Figure
# 680    Bacon, Francis                  Study for Portrait on Folding Bed
# 681    Bacon, Francis                      Portrait of Isabel Rawsthorne
# 682    Bacon, Francis                         Three Figures and Portrait
# 683    Bacon, Francis  Study for Portrait II (after the Life Mask of ...
# 684    Bacon, Francis                             Triptych - August 1972
# 19509  Bacon, Francis                    Second Version of Triptych 1944
# ...

# %%
df_with_specific_cols.iloc[100:300, [0,1,4]]
# Out:
#                                   artist  \
# id
# 1737   Burne-Jones, Sir Edward Coley, Bt
# 1738   Burne-Jones, Sir Edward Coley, Bt
# 1739   Burne-Jones, Sir Edward Coley, Bt
# 20231  Burne-Jones, Sir Edward Coley, Bt
# 1740   Burne-Jones, Sir Edward Coley, Bt
# ...                                  ...
# 7329                       Jones, George
# 7330                       Jones, George
# 7331                       Jones, George
# 7332                       Jones, George
# 7333                       Jones, George
#
#                                                    title  acquisitionYear
# id
# 1737                                      Head of a Girl           1927.0
# 1738                                        Figure Study           1927.0
# 1739   Study of the Head of a Female Attendant for ‘T...           1927.0
# 20231  Study of Iseult for ‘The Marriage of Sir Trist...           1927.0
# 1740              Composition Study for ‘Clerk Saunders’           1927.0
# ...

# %%
df_with_specific_cols['width'].sort_values().head()
# Out:
# id
# 20822            (1):
# 105337    (diameter):
# 98671         (each):
# 76420         (each):
# 91391        (image):
# Name: width, dtype: object

# %%
df_with_specific_cols['width'].sort_values().tail()
# Out:
# id
# 121283    NaN
# 117863    NaN
# 120549    NaN
# 122900    NaN
# 112306    NaN
# Name: width, dtype: object

# %%
pd.to_numeric(df_with_specific_cols['width'], errors="coerce")
# Out:
# id
# 1035      394.0
# 1036      311.0
# 1037      343.0
# 1038      318.0
# 1039      243.0
#           ...
# 122960    305.0
# 122961    305.0
# 121181     45.0
# 112306      NaN
# 127035    508.0
# Name: width, Length: 69201, dtype: float64

# %%
# width type is object
df_with_specific_cols['width']
# Out:
# id
# 1035      394
# 1036      311
# 1037      343
# 1038      318
# 1039      243
#          ...
# 122960    305
# 122961    305
# 121181     45
# 112306    NaN
# 127035    508
# Name: width, Length: 69201, dtype: object

# %%
# now type should be float
df_with_specific_cols.loc[:, "width"] = pd.to_numeric(df_with_specific_cols['width'], errors="coerce")
df_with_specific_cols['width']
# Out:
# id
# 1035      394.0
# 1036      311.0
# 1037      343.0
# 1038      318.0
# 1039      243.0
#           ...
# 122960    305.0
# 122961    305.0
# 121181     45.0
# 112306      NaN
# 127035    508.0
# Name: width, Length: 69201, dtype: float64

# %%
df_with_specific_cols.loc[:, "height"] = pd.to_numeric(df_with_specific_cols['width'], errors="coerce")
df_with_specific_cols['height']
# Out:
# id
# 1035      394.0
# 1036      311.0
# 1037      343.0
# 1038      318.0
# 1039      243.0
#           ...
# 122960    305.0
# 122961    305.0
# 121181     45.0
# 112306      NaN
# 127035    508.0
# Name: height, Length: 69201, dtype: float64

# %%
area = df_with_specific_cols['width'] * df_with_specific_cols['height'] 
area
# Out:
# id
# 1035      155236.0
# 1036       96721.0
# 1037      117649.0
# 1038      101124.0
# 1039       59049.0
#             ...
# 122960     93025.0
# 122961     93025.0
# 121181      2025.0
# 112306         NaN
# 127035    258064.0
# Length: 69201, dtype: float64

# %%
df_with_specific_cols = df_with_specific_cols.assign(area=area)
df_with_specific_cols["area"].max()
# Out:
# 143041600.0

# %%
df_with_specific_cols["area"].idxmax()
# Out:
# 5535

# %%
df_with_specific_cols.loc[df_with_specific_cols["area"].idxmax(), :]
# Out:
# artist                                  Gormley, Antony
# title                                 Natural Selection
# medium             Metal, wood, glass, plastic and food
# year                                               1981
# acquisitionYear                                    1983
# width                                             11960
# height                                            11960
# units                                                mm
# area                                        1.43042e+08
# Name: 5535, dtype: object

# %%
small_df = df_with_specific_cols.iloc[49980:50019, :].copy()
small_df
# Out:
#                   artist            title                         medium  \
# id
# 16412               Wols       [no title]               Etching on paper
# 16413               Wols       [no title]  Etching and drypoint on paper
# 16414               Wols       [no title]  Etching and drypoint on paper
# 16415               Wols       [no title]  Etching and drypoint on paper
# 16416               Wols       [no title]  Etching and drypoint on paper
# 16417               Wols       [no title]               Etching on paper
# 16418               Wols       [no title]  Etching and drypoint on paper
# 16419               Wols       [no title]  Etching and drypoint on paper
# 16420               Wols       [no title]  Etching and drypoint on paper
# 16421               Wols       [no title]  Etching and drypoint on paper
# 16422               Wols       [no title]  Etching and drypoint on paper
# 16423               Wols       [no title]               Etching on paper
# ...

# %%
grouped = small_df.groupby("artist")
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
# Transform
# Equivalent of editing by hand:
# Make a case when there is no data to infer
# small_df.loc[[11838, 16441], 'medium'] = np.nan
def fill_values(series):
    values_counted = series.value_counts()
    if values_counted.empty:
        return series
    most_frequent = values_counted.index[0]
    new_medium = series.fillna(most_frequent)
    return new_medium

# %%
# BUILT-INS
# Transform

grouped_mediums = small_df.groupby('artist')['medium']
small_df.loc[:, 'medium'] = grouped_mediums.transform(fill_values)
small_df
# Out:
#                   artist            title                         medium  \
# id
# 16412               Wols       [no title]               Etching on paper
# 16413               Wols       [no title]  Etching and drypoint on paper
# 16414               Wols       [no title]  Etching and drypoint on paper
# 16415               Wols       [no title]  Etching and drypoint on paper
# 16416               Wols       [no title]  Etching and drypoint on paper
# 16417               Wols       [no title]               Etching on paper
# 16418               Wols       [no title]  Etching and drypoint on paper
# 16419               Wols       [no title]  Etching and drypoint on paper
# 16420               Wols       [no title]  Etching and drypoint on paper
# 16421               Wols       [no title]  Etching and drypoint on paper
# 16422               Wols       [no title]  Etching and drypoint on paper
# 16423               Wols       [no title]               Etching on paper
# ...

# %%
# Min
df_with_specific_cols.groupby('artist').agg(np.min)
df_with_specific_cols.groupby('artist').min()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-b2c6a803471f> in <module>
#       1 # Min
#       2 # df_with_specific_cols.groupby('artist').agg(np.min)
# ----> 3 df_with_specific_cols.groupby('artist').min()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in min(self, numeric_only, min_count)
#    1549     @doc(_groupby_agg_method_template, fname="min", no=False, mc=-1)
#    1550     def min(self, numeric_only: bool = False, min_count: int = -1):
# -> 1551         return self._agg_general(
#    1552             numeric_only=numeric_only, min_count=min_count, alias="min", npfunc=np.min
#    1553         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#     997         # try a cython aggregation if we can
#     998         try:
# ...

# %%
grouped_titles = df_with_specific_cols.groupby("title")
title_counts = grouped_titles.size().sort_values(ascending=False)
title_counts
# Out:
# title
# [title not known]                           3572
# Blank                                       3031
# [blank]                                     2482
# [no title]                                  1874
# Untitled                                     639
#                                             ...
# Salisbury Madonna                              1
# Salisbury Cathedral from the Meadows (2)       1
# Salisbury Cathedral from the Meadows (1)       1
# Salisbury Cathedral from the East              1
# ! 1971                                         1
# Length: 43531, dtype: int64

# %%
condition = lambda x: len(x.index) > 1
dup_titles_df = grouped_titles.filter(condition)
dup_titles_df.sort_values('title', inplace=True)
dup_titles_df
# Out:
#                 artist                 title  \
# id
# 20571     Scully, Sean                    #1
# 21345  Dunham, Carroll                    #1
# 21346  Dunham, Carroll                    #2
# 20572     Scully, Sean                    #2
# 21347  Dunham, Carroll                    #3
# ...                ...                   ...
# 97431     Warhol, Andy  “The Runaway Pigeon”
# 97408     Warhol, Andy  “The Runaway Pigeon”
# 97409     Warhol, Andy  “The Runaway Pigeon”
# 97428     Warhol, Andy  “The Summer Dancers”
# 97427     Warhol, Andy  “The Summer Dancers”
#
#                                        medium  year  acquisitionYear  width  \
# id
# 20571                       Aquatint on paper  1992           1992.0  117.0
# 21345                       Drypoint on paper  1989           2002.0  392.0
# 21346                       Drypoint on paper  1989           2002.0  392.0
# 20572                       Aquatint on paper  1992           1992.0  323.0
# ...

# %%
acquisition_years = dup_titles_df.groupby("acquisitionYear").size()
acquisition_years.plot()
# Out:
# <AxesSubplot:xlabel='acquisitionYear'>

# %%
import matplotlib.pyplot as plt

# %%
# Add axis labels
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_years.plot(ax=subplot)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
# fig.show()
# Out:
# Text(0, 0.5, 'Artworks Acquired')

# %%
# Increase ticks granularity
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_years.plot(ax=subplot)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
# fig.show()

# %%
# Rotate X ticks
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_years.plot(ax=subplot, rot=45)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
# fig.show()

# %%
# Add log scale
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_years.plot(ax=subplot, rot=45, logy=True)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
# fig.show()

# %%
# Add grid
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_years.plot(ax=subplot, rot=45, logy=True, grid=True)
subplot.set_xlabel("Acquisition Year")
subplot.set_ylabel("Artworks Acquired")
subplot.locator_params(nbins=40, axis='x')
# fig.show()

# %%
# Set fonts
title_font = {'family': 'source sans pro',
        'color':  'darkblue',
        'weight': 'normal',
        'size': 20,
        }
labels_font = {'family': 'consolas',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_years.plot(ax=subplot, rot=45, logy=True, grid=True)
subplot.set_xlabel("Acquisition Year", fontdict=labels_font, labelpad=10)
subplot.set_ylabel("Artworks Acquired", fontdict=labels_font)
subplot.locator_params(nbins=40, axis='x')
subplot.set_title("Tate Gallery Acquisitions", fontdict=title_font)
# fig.show()
# Out:
# Text(0.5, 1.0, 'Tate Gallery Acquisitions')
# findfont: Font family ['source sans pro'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['consolas'] not found. Falling back to DejaVu Sans.

# %%
# Save to files
fig.savefig('plot.png')
fig.savefig('plot.svg', format='svg')
